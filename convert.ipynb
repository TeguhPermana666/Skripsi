# %%
from PIL import Image
import csv
import os
def image_to_csv(image_path, label, output_csv_path):
    # Open the image
    img = Image.open(image_path)

    # Convert the image to grayscale
    img = img.convert('L')

    # Resize the image to 28x28 pixels (Fashion MNIST image size)
    img = img.resize((28, 28), Image.ANTIALIAS)

    # Get pixel data
    pixel_data = list(img.getdata())

    # Reshape the pixel data to 28x28 array
    pixel_array = [pixel_data[i:i+28] for i in range(0, len(pixel_data), 28)]

    # Flatten the pixel array
    flat_pixel_array = [pixel for row in pixel_array for pixel in row]

    # Add the label to the beginning of the pixel values
    csv_row = [label] + flat_pixel_array

    # Save pixel values and label to CSV file
    with open(output_csv_path, 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(['label'] + [f'pixel{i+1}' for i in range(784)])  # Header
        csvwriter.writerow(csv_row)

    print(f"Image converted and saved to {output_csv_path}")

def process_images_in_folder(folder_path):
    # Iterate over files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            # Assuming the label is in the filename (adjust this part based on your filenames)
            label = int(filename.split('_')[0])  # Extract label from filename
            image_path = os.path.join(folder_path, filename)

            # Replace 'output.csv' with the desired CSV filename
            csv_filename = 'ankle_boot.csv'

            # Convert image to CSV
            image_to_csv(image_path, csv_filename, label)

if __name__ == "__main__":
    # Replace 'path/to/your/image.jpg' with the path to your image file
    input_image_path = '901.jpg'

    # Replace 'output.csv' with the desired CSV file name
    output_csv_path = 'output_901.csv'

    # Replace 'label_value' with the desired label for your image
    label_value = 'Tas'

    # image_to_csv(input_image_path, label_value, output_csv_path)
    process_images_in_folder(r"Dataset\Ankle Boot")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\UP\Code\convert.ipynb Cell 1 in <cell line: 48>()
#      <a href='vscode-notebook-cell:/d%3A/UP/Code/convert.ipynb#W0sZmlsZQ%3D%3D?line=55'>56</a> label_value = 'Tas'
#      <a href='vscode-notebook-cell:/d%3A/UP/Code/convert.ipynb#W0sZmlsZQ%3D%3D?line=57'>58</a> # image_to_csv(input_image_path, label_value, output_csv_path)
# ---> <a href='vscode-notebook-cell:/d%3A/UP/Code/convert.ipynb#W0sZmlsZQ%3D%3D?line=58'>59</a> process_images_in_folder(r"Dataset\Ankle Boot")
#
# d:\UP\Code\convert.ipynb Cell 1 in process_images_in_folder(folder_path)
#      <a href='vscode-notebook-cell:/d%3A/UP/Code/convert.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a> for filename in os.listdir(folder_path):
# ...

# %%
from PIL import Image
import csv
import os

def image_to_csv(image_path, label, output_csv_path):
    # Open the image
    img = Image.open(image_path)

    # Convert the image to grayscale
    img = img.convert('L')

    # Resize the image to 28x28 pixels (Fashion MNIST image size)
    img = img.resize((28, 28), Image.ANTIALIAS)

    # Get pixel data
    pixel_data = list(img.getdata())

    # Reshape the pixel data to a 28x28 array
    pixel_array = [pixel_data[i:i + 28] for i in range(0, len(pixel_data), 28)]

    # Flatten the pixel array
    flat_pixel_array = [pixel for row in pixel_array for pixel in row]

    # Add the label to the beginning of the pixel values
    csv_row = [label] + flat_pixel_array

    # Save pixel values and label to the CSV file
    with open(output_csv_path, 'w', newline='') as csvfile:
        csvwriter = csv.writer(csvfile)
        csvwriter.writerow(['label'] + [f'pixel{i + 1}' for i in range(784)])  # Header
        csvwriter.writerow(csv_row)

    print(f"Image converted and saved to {output_csv_path}")

def process_images_in_folder(folder_path):
    # Iterate over files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            # Assuming the label is in the filename (adjust this part based on your filenames)
            label = os.path.splitext(filename)[0]  # Extract label from filename without extension
            image_path = os.path.join(folder_path, filename)

            # Replace 'output.csv' with the desired CSV filename
            csv_filename = 'ankle_boot.csv'

            # Convert image to CSV
            image_to_csv(image_path, label, csv_filename)

if __name__ == "__main__":
    process_images_in_folder(r"Dataset\Ankle Boot")
# Out:
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# ...

# %%
from PIL import Image,ImageFilter
import csv
import os

def image_to_csv(image_path, label, output_csv_path):
    # Open the image
    img = Image.open(image_path)

    # Convert the image to grayscale
    img = img.convert('L')

    # Resize the image to 28x28 pixels (Fashion MNIST image size)
    img = img.resize((28, 28), ImageFilter.ANTIALIAS)

    # Get pixel data
    pixel_data = list(img.getdata())

    # Reshape the pixel data to a 28x28 array
    pixel_array = [pixel_data[i:i + 28] for i in range(0, len(pixel_data), 28)]

    # Flatten the pixel array
    flat_pixel_array = [pixel for row in pixel_array for pixel in row]

    # Add the label to the beginning of the pixel values
    csv_row = [label] + flat_pixel_array

    # Save pixel values and label to the CSV file
    with open(output_csv_path, 'a', newline='') as csvfile:  # Use 'a' for append mode
        csvwriter = csv.writer(csvfile)
        # Check if the file is empty, if yes, write the header
        if os.stat(output_csv_path).st_size == 0:
            csvwriter.writerow(['label'] + [f'pixel{i + 1}' for i in range(784)])  # Header
        csvwriter.writerow(csv_row)

    print(f"Image converted and saved to {output_csv_path}")

def process_images_in_folder(folder_path):
    # Iterate over files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            # Assuming the label is in the filename (adjust this part based on your filenames)
            label = os.path.splitext(filename)[0]  # Extract label from filename without extension
            image_path = os.path.join(folder_path, filename)

            # Replace 'output.csv' with the desired CSV filename
            csv_filename = 'ankle_boot.csv'

            # Convert image to CSV
            image_to_csv(image_path, label, csv_filename)

if __name__ == "__main__":
    process_images_in_folder(r"Dataset\Ankle Boot")
# Out:
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# Image converted and saved to ankle_boot.csv
# ...

# %% [markdown]
# - Correct

# %%
from PIL import Image
import csv
import os

def image_to_csv(image_path, label, output_csv_path):
    # Open the image
    img = Image.open(image_path)

    # Convert the image to grayscale
    img = img.convert('L')

    # Resize the image to 28x28 pixels (Fashion MNIST image size)
    img = img.resize((28, 28), Image.ANTIALIAS)

    # Get pixel data
    pixel_data = list(img.getdata())

    # Reshape the pixel data to a 28x28 array
    pixel_array = [pixel_data[i:i + 28] for i in range(0, len(pixel_data), 28)]

    # Flatten the pixel array
    flat_pixel_array = [pixel for row in pixel_array for pixel in row]

    # Add the label to the beginning of the pixel values
    csv_row = [label] + flat_pixel_array

    # Save pixel values and label to the CSV file
    with open(output_csv_path, 'a', newline='') as csvfile:  # Use 'a' for append mode
        csvwriter = csv.writer(csvfile)
        # Check if the file is empty, if yes, write the header
        if os.stat(output_csv_path).st_size == 0:
            csvwriter.writerow(['label'] + [f'pixel{i + 1}' for i in range(784)])  # Header
        csvwriter.writerow(csv_row)

    print(f"Image converted and saved to {output_csv_path}")

def process_images_in_folder(folder_path):
    # Iterate over folders in the main folder
    for label in os.listdir(folder_path):
        label_path = os.path.join(folder_path, label)
        if os.path.isdir(label_path):
            # Iterate over files in the folder
            for filename in os.listdir(label_path):
                if filename.endswith(".jpg") or filename.endswith(".png") or filename.endswith('.jpeg'):
                    # Assuming the label is in the folder name
                    image_path = os.path.join(label_path, filename)

                    # Use the folder name as the CSV filename
                    csv_filename = f'{label}.csv'

                    # Convert image to CSV
                    image_to_csv(image_path, label, csv_filename)

if __name__ == "__main__":
    process_images_in_folder(r"Test")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16072\1447684607.py:13: DeprecationWarning: ANTIALIAS is deprecated and will be removed in Pillow 10 (2023-07-01). Use LANCZOS or Resampling.LANCZOS instead.
#   img = img.resize((28, 28), Image.ANTIALIAS)
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# Image converted and saved to Ankle Boot.csv
# ...

# %% [markdown]
# - Check the result of the load dataset

# %%
from PIL import Image
import csv
import numpy as np
import pandas as pd

data = pd.read_csv(r'EachLabel\Ankle Boot.csv')

# Extract label and pixel data from the DataFrame
label = data['label'][0]  # Assuming 'label' is the name of the label column
pixel_values = data.iloc[0, 1:].astype(int).tolist()

# Reshape pixel values to 28x28 array
pixel_array = np.array(pixel_values).reshape(28, 28)

# Create an image from the pixel array
img = Image.fromarray(pixel_array.astype('uint8'), 'L')

# Display the image
img.show()
img.save(f"ExampleOutput_{label}.png")
